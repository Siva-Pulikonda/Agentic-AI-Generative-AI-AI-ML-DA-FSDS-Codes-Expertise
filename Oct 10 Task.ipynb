# %%
2       # if you enter a number and execute you will get a number
# Out:
# 2

# %%
2+3    # Addition
# Out:
# 5

# %%
5-2 # subtraction
# Out:
# 3

# %%
_+10    # why 13 because it is taking previous output in the underscore place
# Out:
# 13

# %%
5+5*5-2
# Out:
# 28

# %%
(5+5)*5-2
# Out:
# 48

# %%
10 * 5   # Multiplication
# Out:
# 50

# %%
10/5   # 2.0 Beacuse one / gives float division
# Out:
# 2.0

# %%
10//5   # 2 beacuse two // gives int division
# Out:
# 2

# %%
27 % 5    # % gives Remainder
# Out:
# 2

# %%
5**2  # Square
# Out:
# 25

# %%
5**3   # 5 cube
# Out:
# 125

# %%
5**4   # 5 power 4
# Out:
# 625

# %%
10+2
10/2
10-2     # here only printed the last line, if you want to print the whole code use print
# Out:
# 8

# %%
print(10+2)
print(10/2)
print(10-2)
# Out:
# 12
# 5.0
# 8

# %%
# Print a Statement

print('I am Studying FSDS With Gen Ai and Agentic Ai in Naresh IT Under Prakash Senapathi Sir')
# Out:
# I am Studying FSDS With Gen Ai and Agentic Ai in Naresh IT Under Prakash Senapathi Sir
